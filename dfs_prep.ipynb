# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import csv
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
folder_path="/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs"

# %%
files = os.listdir(folder_path)
filepaths=[]
for i in range(len(files)):
  filepath = os.path.join(folder_path, files[i])
  filepaths.append(filepath)
filepaths
# Out:
# ['/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(1)_channel(1).csv',
#  '/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(1)_channel(2).csv',
#  '/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(2)_channel(1).csv',
#  '/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(2)_channel(2).csv',
#  '/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(3)_channel(1).csv',
#  '/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(3)_channel(2).csv',
#  '/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(4)_channel(1).csv',
#  '/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(4)_channel(2).csv',
#  '/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(5)_channel(1).csv',
#  '/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/CSVs/test(5)_channel(2).csv',
# ...

# %%
shapes=[]
for i in range(len(filepaths)):
  df=pd.read_csv(filepaths[i])
  shapes.append(df.shape)
filenames=[filename.split(".csv")[0] for filename in files]
filename_dict = dict(zip(filenames, shapes))
filename_dict
# Out:
# {'test(1)_channel(1)': (79, 7683),
#  'test(1)_channel(2)': (79, 7683),
#  'test(2)_channel(1)': (79, 5123),
#  'test(2)_channel(2)': (79, 5123),
#  'test(3)_channel(1)': (79, 5123),
#  'test(3)_channel(2)': (79, 5123),
#  'test(4)_channel(1)': (79, 11523),
#  'test(4)_channel(2)': (79, 11523),
#  'test(5)_channel(1)': (79, 3843),
#  'test(5)_channel(2)': (79, 3843),
#  'test(6)_channel(1)': (79, 7683),
#  'test(6)_channel(2)': (79, 7683),
#  'test(7)_channel(1)': (79, 7683),
#  'test(7)_channel(2)': (79, 7683),
#  'test(8)_channel(1)': (79, 5123),
#  'test(8)_channel(2)': (79, 5123),
#  'test(9)_channel(1)': (79, 5123),
#  'test(9)_channel(2)': (79, 5123),
#  'test(10)_channel(1)': (79, 11523),
#  'test(10)_channel(2)': (79, 11523),
#  'test(11)_channel(1)': (79, 11523),
#  'test(11)_channel(2)': (79, 11523)}

# %%
dfs_dic = {}
for filename in files:
    # Check if the file is a CSV file
    if filename.endswith('.csv'):
        # Construct the full path to the file
        file_path = os.path.join(folder_path, filename)

        # Load the CSV file into a Pandas DataFrame
        df = pd.read_csv(file_path)
        df = df.iloc[:, 1:]

        # Store the DataFrame in the dictionary with the filename as the key
        dfs_dic[filename] = df

# %%
files
# Out:
# ['test(1)_channel(1).csv',
#  'test(1)_channel(2).csv',
#  'test(2)_channel(1).csv',
#  'test(2)_channel(2).csv',
#  'test(3)_channel(1).csv',
#  'test(3)_channel(2).csv',
#  'test(4)_channel(1).csv',
#  'test(4)_channel(2).csv',
#  'test(5)_channel(1).csv',
#  'test(5)_channel(2).csv',
#  'test(6)_channel(1).csv',
#  'test(6)_channel(2).csv',
#  'test(7)_channel(1).csv',
#  'test(7)_channel(2).csv',
#  'test(8)_channel(1).csv',
#  'test(8)_channel(2).csv',
#  'test(9)_channel(1).csv',
#  'test(9)_channel(2).csv',
#  'test(10)_channel(1).csv',
#  'test(10)_channel(2).csv',
#  'test(11)_channel(1).csv',
#  'test(11)_channel(2).csv']

# %%
df_1_1,df_2_1,df_3_1,df_4_1,df_5_1,df_6_1,df_7_1,df_8_1,df_9_1,df_10_1,df_11_1=dfs_dic[ 'test(1)_channel(1).csv'],dfs_dic[ 'test(2)_channel(1).csv'],dfs_dic[ 'test(3)_channel(1).csv'],dfs_dic[ 'test(4)_channel(1).csv'],dfs_dic[ 'test(5)_channel(1).csv'],dfs_dic[ 'test(6)_channel(1).csv'],dfs_dic[ 'test(7)_channel(1).csv'],dfs_dic[ 'test(8)_channel(1).csv'],dfs_dic[ 'test(9)_channel(1).csv'],dfs_dic[ 'test(10)_channel(1).csv'],dfs_dic[ 'test(11)_channel(1).csv']
df_1_2,df_2_2,df_3_2,df_4_2,df_5_2,df_6_2,df_7_2,df_8_2,df_9_2,df_10_2,df_11_2=dfs_dic[ 'test(1)_channel(2).csv'],dfs_dic[ 'test(2)_channel(2).csv'],dfs_dic[ 'test(3)_channel(2).csv'],dfs_dic[ 'test(4)_channel(2).csv'],dfs_dic[ 'test(5)_channel(2).csv'],dfs_dic[ 'test(6)_channel(2).csv'],dfs_dic[ 'test(7)_channel(2).csv'],dfs_dic[ 'test(8)_channel(2).csv'],dfs_dic[ 'test(9)_channel(2).csv'],dfs_dic[ 'test(10)_channel(2).csv'],dfs_dic[ 'test(11)_channel(2).csv']

# %%
df1 = pd.DataFrame()
df1 = pd.DataFrame()
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()
df10 = pd.DataFrame()
df11 = pd.DataFrame()

for col in df_1_1.columns:
  #take all values in the cell and make tuble of it in the new df
  df1[col] = list(zip(df_1_1[col], df_1_2[col]))
#remove the last 2 col that have same target value but as duplicat in tuble
df1 = df1.drop(columns=df.columns[-2:])
#concat the last 2 col of the old df before zipping to take the target not as tuple but as solo value
df1 = pd.concat([df1, df_1_1.iloc[:,-2:]], axis=1)

for col in df_2_1.columns:
  df2[col] = list(zip(df_2_1[col], df_2_2[col]))
df2 = df2.drop(columns=df.columns[-2:])
df2 = pd.concat([df2, df_2_1.iloc[:,-2:]], axis=1)

for col in df_3_1.columns:
  df3[col] = list(zip(df_3_1[col], df_3_2[col]))
df3 = df3.drop(columns=df.columns[-2:])
df3 = pd.concat([df3, df_3_1.iloc[:,-2:]], axis=1)

for col in df_4_1.columns:
  df4[col] = list(zip(df_4_1[col], df_4_2[col]))
df4 = df4.drop(columns=df.columns[-2:])
df4 = pd.concat([df4, df_4_1.iloc[:,-2:]], axis=1)

for col in df_5_1.columns:
  df5[col] = list(zip(df_5_1[col], df_5_2[col]))
df5 = df5.drop(columns=df.columns[-2:])
df5 = pd.concat([df5, df_5_1.iloc[:,-2:]], axis=1)

for col in df_6_1.columns:
  df6[col] = list(zip(df_6_1[col], df_6_2[col]))
df6 = df6.drop(columns=df.columns[-2:])
df6 = pd.concat([df6, df_6_1.iloc[:,-2:]], axis=1)

for col in df_7_1.columns:
  df7[col] = list(zip(df_7_1[col], df_7_2[col]))
df7 = df7.drop(columns=df.columns[-2:])
df7 = pd.concat([df7, df_7_1.iloc[:,-2:]], axis=1)

for col in df_8_1.columns:
  df8[col] = list(zip(df_8_1[col], df_8_2[col]))
df8 = df8.drop(columns=df.columns[-2:])
df8 = pd.concat([df8, df_8_1.iloc[:,-2:]], axis=1)

for col in df_9_1.columns:
  df9[col] = list(zip(df_9_1[col], df_9_2[col]))
df9 = df9.drop(columns=df.columns[-2:])
df9 = pd.concat([df9, df_9_1.iloc[:,-2:]], axis=1)

for col in df_10_1.columns:
  df10[col] = list(zip(df_10_1[col], df_10_2[col]))
df10 = df10.drop(columns=df.columns[-2:])
df10 = pd.concat([df10, df_10_1.iloc[:,-2:]], axis=1)

for col in df_11_1.columns:
  df11[col] = list(zip(df_11_1[col], df_11_2[col]))
df11 = df11.drop(columns=df.columns[-2:])
df11 = pd.concat([df11, df_11_1.iloc[:,-2:]], axis=1)

# %%
df1.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_1.csv")
df2.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_2.csv")
df3.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_3.csv")
df4.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_4.csv")
df5.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_5.csv")
df6.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_6.csv")
df7.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_7.csv")
df8.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_8.csv")
df9.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_9.csv")
df10.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_10.csv")
df11.to_csv("/content/drive/MyDrive/TrainING/Group 1 (ADHD)/Dataset 3/tests_CSVs/test_11.csv")

# %%
dfs=[]
dfs.append(df1)
dfs.append(df2)
dfs.append(df3)
dfs.append(df4)
dfs.append(df5)
dfs.append(df6)
dfs.append(df7)
dfs.append(df8)
dfs.append(df9)
dfs.append(df10)
dfs.append(df11)

# %%
for i in range(len(dfs)):
  print(f"{i+1}:{dfs[i].shape}")
# Out:
# 1:(79, 7682)
# 2:(79, 5122)
# 3:(79, 5122)
# 4:(79, 11522)
# 5:(79, 3842)
# 6:(79, 7682)
# 7:(79, 7682)
# 8:(79, 5122)
# 9:(79, 5122)
# 10:(79, 11522)
# 11:(79, 11522)
